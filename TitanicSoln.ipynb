# %%
import pandas as pd
import numpy as np

# %%
traindata= pd.read_csv("C:/Users/dhans/Desktop/train.csv")
testdata= pd.read_csv("C:/Users/dhans/Desktop/test.csv")

# %%
traindata.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
traindata.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
import matplotlib.pyplot as plt

# %%
print(traindata.isnull().sum())
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
x=traindata['Age'].mean()
x
traindata['Age'].fillna(x, inplace=True)
traindata['Age']
# Out:
# 0      22.000000
# 1      38.000000
# 2      26.000000
# 3      35.000000
# 4      35.000000
# 5      29.699118
# 6      54.000000
# 7       2.000000
# 8      27.000000
# 9      14.000000
# 10      4.000000
# 11     58.000000
# 12     20.000000
# 13     39.000000
# 14     14.000000
# 15     55.000000
# 16      2.000000
# 17     29.699118
# 18     31.000000
# 19     29.699118
# 20     35.000000
# 21     34.000000
# 22     15.000000
# 23     28.000000
# 24      8.000000
# 25     38.000000
# 26     29.699118
# 27     19.000000
# 28     29.699118
# 29     29.699118
#          ...
# 861    21.000000
# 862    48.000000
# 863    29.699118
# 864    24.000000
# 865    42.000000
# 866    27.000000
# 867    31.000000
# 868    29.699118
# 869     4.000000
# 870    26.000000
# 871    47.000000
# 872    33.000000
# 873    47.000000
# 874    28.000000
# 875    15.000000
# 876    20.000000
# 877    19.000000
# 878    29.699118
# 879    56.000000
# 880    25.000000
# 881    33.000000
# ...

# %%
x=testdata['Age'].mean()
x
testdata['Age'].fillna(x, inplace=True)
testdata['Age']
# Out:
# 0      34.50000
# 1      47.00000
# 2      62.00000
# 3      27.00000
# 4      22.00000
# 5      14.00000
# 6      30.00000
# 7      26.00000
# 8      18.00000
# 9      21.00000
# 10     30.27259
# 11     46.00000
# 12     23.00000
# 13     63.00000
# 14     47.00000
# 15     24.00000
# 16     35.00000
# 17     21.00000
# 18     27.00000
# 19     45.00000
# 20     55.00000
# 21      9.00000
# 22     30.27259
# 23     21.00000
# 24     48.00000
# 25     50.00000
# 26     22.00000
# 27     22.50000
# 28     41.00000
# 29     30.27259
#          ...
# 388    21.00000
# 389     6.00000
# 390    23.00000
# 391    51.00000
# 392    13.00000
# 393    47.00000
# 394    29.00000
# 395    18.00000
# 396    24.00000
# 397    48.00000
# 398    22.00000
# 399    31.00000
# 400    30.00000
# 401    38.00000
# 402    22.00000
# 403    17.00000
# 404    43.00000
# 405    20.00000
# 406    23.00000
# 407    50.00000
# 408    30.27259
# 409     3.00000
# 410    30.27259
# 411    37.00000
# ...

# %%
fig = plt.figure(figsize=(8,4))
ax1 = fig.add_subplot(121)
ax1.set_xlabel('Pclass')
ax1.set_ylabel('Survived')
ax1.set_title("Survival Based On Pclass")
temp1=traindata['Pclass'].value_counts(ascending=True)
temp1.plot(kind='bar')#if Pclass> then Survival>

# %%
fig1 = plt.figure(figsize=(8,4))
ax2 = fig1.add_subplot(121)
ax2.set_xlabel('Sex')
ax2.set_ylabel('Survived')
ax2.set_title("Survival Based On Sex")
temp2=traindata['Sex'].value_counts(ascending=False)
temp2.plot(kind='bar')#if Sex=m then Survival>

# %%
fig2 = plt.figure(figsize=(8,4))
ax3 = fig2.add_subplot(121)
ax3.set_xlabel('SibSp')
ax3.set_ylabel('Survived')
ax3.set_title("Survival Based On SibSp")
temp3=traindata['SibSp'].value_counts(ascending=True)
temp3.plot(kind='bar')#if Sibsp< then Survival>

# %%
fig5 = plt.figure(figsize=(8,4))
ax5 = fig5.add_subplot(121)
ax5.set_xlabel('Embarked')
ax5.set_ylabel('Survived')
ax5.set_title("Survival Based On Embarked")
temp4=traindata['Embarked'].value_counts(ascending=True)
temp4.plot(kind='bar')#if Parch< then Survival>

# %%
fig3 = plt.figure(figsize=(8,4))
ax4 = fig3.add_subplot(121)
ax4.set_xlabel('Parch')
ax4.set_ylabel('Survived')
ax4.set_title("Survival Based On Parch")
temp4=traindata['Parch'].value_counts(ascending=True)
temp4.plot(kind='bar')#if Parch< then Survival>

# %%
temp4 = pd.crosstab(traindata['Sex'], traindata['Pclass'])
temp4.plot(kind='bar', stacked=True, color=['red','blue','green'], grid=False)

# %%
temp4 = pd.crosstab(traindata['Parch'], traindata['SibSp'])
temp4.plot(kind='bar', stacked=True, color=['red','blue','green'], grid=False)

# %%
print(traindata[["Sex", "Survived"]].groupby(['Sex'], as_index=False).mean().sort_values(by='Survived', ascending=False))
#females survived more
# Out:
#       Sex  Survived
# 0  female  0.742038
# 1    male  0.188908

# %%
print(traindata[['Pclass', 'Survived']].groupby(['Pclass'], as_index=False).mean().sort_values(by='Survived', ascending=False))
#pclass=1 survived more
# Out:
#    Pclass  Survived
# 0       1  0.629630
# 1       2  0.472826
# 2       3  0.242363

# %%
print(traindata[["SibSp", "Survived"]].groupby(['SibSp'], as_index=False).mean().sort_values(by='Survived', ascending=False))
#ppl with sibsp 1 survived more
# Out:
#    SibSp  Survived
# 1      1  0.535885
# 2      2  0.464286
# 0      0  0.345395
# 3      3  0.250000
# 4      4  0.166667
# 5      5  0.000000
# 6      8  0.000000

# %%
print(traindata[["Parch", "Survived"]].groupby(['Parch'], as_index=False).mean().sort_values(by='Survived', ascending=False))
#ppl with parch 3 survived more
# Out:
#    Parch  Survived
# 3      3  0.600000
# 1      1  0.550847
# 2      2  0.500000
# 0      0  0.343658
# 5      5  0.200000
# 4      4  0.000000
# 6      6  0.000000

# %%
print(traindata[["Cabin", "Survived"]].groupby(['Cabin'], as_index=False).mean().sort_values(by='Survived', ascending=False))
# Out:
#        Cabin  Survived
# 73   C62 C64       1.0
# 97       D21       1.0
# 94       D17       1.0
# 95       D19       1.0
# 60      C148       1.0
# 96       D20       1.0
# 58      C126       1.0
# 57      C125       1.0
# 127      E40       1.0
# 111      D56       1.0
# 116     E101       1.0
# 125      E36       1.0
# 130      E49       1.0
# 51      C106       1.0
# 50      C104       1.0
# 49      C103       1.0
# 48      C101       1.0
# 47   B96 B98       1.0
# 131      E50       1.0
# 99       D28       1.0
# 93       D15       1.0
# 65       C32       1.0
# 87       C93       1.0
# 77       C70       1.0
# 118     E121       1.0
# 84       C90       1.0
# 119      E17       1.0
# 120      E24       1.0
# 81       C85       1.0
# 117      E12       1.0
# ..       ...       ...
# 26       B38       0.0
# 25       B37       0.0
# 23       B30       0.0
# 16      B102       0.0
# 52      C110       0.0
# 14        A7       0.0
# 12        A5       0.0
# 11       A36       0.0
# ...

# %%
traindata["Embarked"].fillna('S', inplace=True)
testdata["Embarked"].fillna('S', inplace=True)
traindata['Place'] = traindata['Embarked'].map( {'S': 0, 'C': 1, 'Q': 2} ).astype(int)
testdata['Place'] = testdata['Embarked'].map({'S': 0, 'C': 1, 'Q': 2}).astype(int)

# %%
traindata.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
testdata.head(10)
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# 5          897       3                    Svensson, Mr. Johan Cervin    male
# 6          898       3                          Connolly, Miss. Kate  female
# 7          899       2                  Caldwell, Mr. Albert Francis    male
# 8          900       3     Abrahim, Mrs. Joseph (Sophie Halaut Easu)  female
# 9          901       3                       Davies, Mr. John Samuel    male
#
#     Age  SibSp  Parch     Ticket     Fare Cabin Embarked  Place
# ...

# %%
print(traindata.isnull().sum())
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         0
# Place            0
# dtype: int64

# %%
print(testdata.isnull().sum())
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# Place            0
# dtype: int64

# %%
testdata["Fare"].fillna(testdata["Fare"].mean(), inplace=True)

# %%
print(testdata.isnull().sum())
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          327
# Embarked         0
# Place            0
# dtype: int64

# %%
traindata['Family']= traindata['SibSp']+traindata['Parch']
testdata['Family']= testdata['SibSp']+testdata['Parch']

# %%
traindata.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Place  Family
# 0      0         A/5 21171   7.2500   NaN        S      0       1
# 1      0          PC 17599  71.2833   C85        C      1       1
# 2      0  STON/O2. 3101282   7.9250   NaN        S      0       0
# ...

# %%
traindata['Gender'] = traindata['Sex'].map( {'male': 2, 'female': 1} ).astype(int)
testdata['Gender'] = testdata['Sex'].map({'male': 2, 'female': 1}).astype(int)

# %%
traindata.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Place  Family  Gender
# 0      0         A/5 21171   7.2500   NaN        S      0       1       2
# 1      0          PC 17599  71.2833   C85        C      1       1       1
# 2      0  STON/O2. 3101282   7.9250   NaN        S      0       0       1
# ...

# %%
testdata.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked  Place  Family  Gender
# 0  34.5      0      0   330911   7.8292   NaN        Q      2       0       2
# 1  47.0      1      0   363272   7.0000   NaN        S      0       1       1
# 2  62.0      0      0   240276   9.6875   NaN        Q      2       0       2
# 3  27.0      0      0   315154   8.6625   NaN        S      0       0       2
# 4  22.0      1      1  3101298  12.2875   NaN        S      0       2       1

# %%
traindata['PG']= traindata['Pclass']*traindata['Gender']
testdata['PG']=testdata['Pclass']*testdata['Gender']
testdata.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked  Place  Family  Gender  \
# 0  34.5      0      0   330911   7.8292   NaN        Q      2       0       2
# 1  47.0      1      0   363272   7.0000   NaN        S      0       1       1
# 2  62.0      0      0   240276   9.6875   NaN        Q      2       0       2
# 3  27.0      0      0   315154   8.6625   NaN        S      0       0       2
# 4  22.0      1      1  3101298  12.2875   NaN        S      0       2       1
#
#    PG
# 0   6
# 1   3
# 2   4
# ...

# %%
traindata.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Place  Family  Gender  PG
# 0      0         A/5 21171   7.2500   NaN        S      0       1       2   6
# 1      0          PC 17599  71.2833   C85        C      1       1       1   1
# 2      0  STON/O2. 3101282   7.9250   NaN        S      0       0       1   3
# ...

# %%
from sklearn.metrics import make_scorer, accuracy_score

# %%
features=['Pclass', 'Place', 'Family', 'Gender']
xtrain= traindata[features]
ytrain= traindata['Survived']
xtest= testdata[features]

# %%
from sklearn.model_selection import train_test_split #to create validation data set

X_train, X_valid, y_train, y_valid = train_test_split(xtrain, ytrain, test_size=0.2, random_state=0)

# %%
from sklearn.svm import SVC, LinearSVC
from sklearn.ensemble import RandomForestClassifier

# %%
rf_clf = RandomForestClassifier()
rf_clf.fit(X_train, y_train)
pred_rf = rf_clf.predict(X_valid)
acc_rf = accuracy_score(y_valid, pred_rf)

print(acc_rf)
# Out:
# 0.8100558659217877

# %%
dt_clf = DecisionTreeClassifier()
dt_clf.fit(X_train, y_train)
pred_dt = dt_clf.predict(X_valid)
acc_dt = accuracy_score(y_valid, pred_dt)

print(acc_dt)
# Out:
# 0.8212290502793296
